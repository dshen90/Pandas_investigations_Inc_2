# %%
#Import dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
#bring in dataframe

csv='C:/Users/Daniel/Downloads/arrest-data-from-2010-to-present_clean.csv'
df = pd.read_csv(csv,low_memory=False)
df
# Out:
#         Unnamed: 0  Report ID              Arrest Date    Time  Area ID  \
# 0                2    5666570  2019-06-22T00:00:00.000   400.0       15
# 1                8    5666534  2019-06-22T00:00:00.000   240.0       18
# 2                9    5666871  2019-06-22T00:00:00.000  1615.0       12
# 3               10    5666420  2019-06-22T00:00:00.000    16.0       14
# 4               12    5666622  2019-06-22T00:00:00.000   725.0        8
# 5               13    5666460  2019-06-22T00:00:00.000    30.0        3
# 6               14    5666491  2019-06-22T00:00:00.000   110.0       11
# 7               15    5666714  2019-06-22T00:00:00.000   930.0       14
# 8               22    5666549  2019-06-22T00:00:00.000   230.0        9
# 9               23    5666560  2019-06-22T00:00:00.000   341.0       14
# 10              24    5666398  2019-06-22T00:00:00.000     4.0       14
# 11              35  190811567  2019-06-22T00:00:00.000   930.0        8
# ...

# %%
#Set variables for the areas and the crimes

area_names=set(df['Area Name'])
crimes=set(df['Charge Group Description'])

# %%
#Group by Area name to have distinct areas

df.groupby('Area Name').head()
# Out:
#         Unnamed: 0  Report ID              Arrest Date    Time  Area ID  \
# 0                2    5666570  2019-06-22T00:00:00.000   400.0       15
# 1                8    5666534  2019-06-22T00:00:00.000   240.0       18
# 2                9    5666871  2019-06-22T00:00:00.000  1615.0       12
# 3               10    5666420  2019-06-22T00:00:00.000    16.0       14
# 4               12    5666622  2019-06-22T00:00:00.000   725.0        8
# 5               13    5666460  2019-06-22T00:00:00.000    30.0        3
# 6               14    5666491  2019-06-22T00:00:00.000   110.0       11
# 7               15    5666714  2019-06-22T00:00:00.000   930.0       14
# 8               22    5666549  2019-06-22T00:00:00.000   230.0        9
# 9               23    5666560  2019-06-22T00:00:00.000   341.0       14
# 10              24    5666398  2019-06-22T00:00:00.000     4.0       14
# 11              35  190811567  2019-06-22T00:00:00.000   930.0        8
# ...

# %%
#Dataframe for area
df_area=df[['Area Name','Reporting District','Address','Location','Zip Codes','Charge Group Description','Charge Group Code']]
df_area
# Out:
#           Area Name  Reporting District                             Address  \
# 0       N Hollywood                1543     MAGNOLIA                     AV
# 1         Southeast                1842                            IMPERIAL
# 2       77th Street                1293  W  104TH                        ST
# 3           Pacific                1406     CULVER                       BL
# 4           West LA                 853     SANTAMONICA                  BL
# 5         Southwest                 314     ARLINGTON                    AV
# 6         Northeast                1151                            EDGEMONT
# 7           Pacific                1413     3RD                          ST
# 8          Van Nuys                 989                             VENTURA
# 9           Pacific                1479                          MANCHESTER
# 10          Pacific                1432                              VENICE
# ...

# %%
#create groups that sort by area name and return the amount of crimes of each type committed
num_crimes_in_district=df_area.groupby(['Area Name'])["Charge Group Description"].value_counts()
num_crimes_in_district
# Out:
# Area Name    Charge Group Description
# 77th Street  Driving Under Influence           4751
#              Narcotic Drug Laws                3832
#              Miscellaneous Other Violations    3709
#              Moving Traffic Violations         2662
#              Prostitution/Allied               2294
#              Weapon (carry/poss)               1621
#              Vehicle Theft                     1441
#              Aggravated Assault                1420
#              Robbery                           1160
#              Drunkeness                        1115
#              Other Assaults                     867
#              Burglary                           636
#              Larceny                            550
#              Sex (except rape/prst)             275
#              Pre-Delinquency                    238
#              Receive Stolen Property            199
#              Forgery/Counterfeit                144
# ...

# %%
#Create new dataframe of the above groupby and add in a column 'Number of crimes'
plot_df  = pd.DataFrame(num_crimes_in_district)
plot_df.columns = ['Number of Crimes']
plot_df
# Out:
#                                             Number of Crimes
# Area Name   Charge Group Description
# 77th Street Driving Under Influence                     4751
#             Narcotic Drug Laws                          3832
#             Miscellaneous Other Violations              3709
#             Moving Traffic Violations                   2662
#             Prostitution/Allied                         2294
#             Weapon (carry/poss)                         1621
#             Vehicle Theft                               1441
#             Aggravated Assault                          1420
#             Robbery                                     1160
#             Drunkeness                                  1115
#             Other Assaults                               867
#             Burglary                                     636
#             Larceny                                      550
#             Sex (except rape/prst)                       275
# ...

# %%
#Create list of different types of crimes that fall under a similar category
print (crimes)
heavy_crimes =['Aggravated Assault','Homicide','Rape','Robbery',]
bad_for_cars=['Vehicle Theft','Driving Under Influence','Moving Traffic Violations']
white_collar_crimes =['Fraud/Embezzlement','Forgery/Counterfeit','Gambling']
#Create a dataframe for each of the different categories by resetting the indexes to 
#then search for only the crimes that fall in the list specified
hc_locations_df = plot_df.reset_index(inplace=False)[plot_df.reset_index(inplace=False)['Charge Group Description'].isin(heavy_crimes)]
bfc_locations_df = plot_df.reset_index(inplace=False)[plot_df.reset_index(inplace=False)['Charge Group Description'].isin(bad_for_cars)] 
wcc_locations_df = plot_df.reset_index(inplace=False)[plot_df.reset_index(inplace=False)['Charge Group Description'].isin(white_collar_crimes)]
# Out:
# {'Aggravated Assault', 'Weapon (carry/poss)', 'Drunkeness', 'Rape', 'Federal Offenses', 'Moving Traffic Violations', 'Miscellaneous Other Violations', 'Disturbing the Peace', 'Prostitution/Allied', 'Other Assaults', 'Fraud/Embezzlement', 'Disorderly Conduct', 'Robbery', 'Homicide', 'Forgery/Counterfeit', 'Vehicle Theft', 'Sex (except rape/prst)', 'Pre-Delinquency', 'Receive Stolen Property', 'Against Family/Child', 'Liquor Laws', 'Burglary', 'Non-Criminal Detention', 'Gambling', 'Narcotic Drug Laws', 'Driving Under Influence', 'Larceny'}

# %%
#Update the dataframes with the groups back in place
hc_locations_df = hc_locations_df.groupby(['Area Name','Charge Group Description']).sum()
wcc_locations_df= wcc_locations_df.groupby(['Area Name','Charge Group Description']).sum()
bfc_locations_df = bfc_locations_df.groupby(['Area Name','Charge Group Description']).sum()

# %%
hc_locations_df
# Out:
#                                       Number of Crimes
# Area Name   Charge Group Description
# 77th Street Aggravated Assault                    1420
#             Homicide                                88
#             Rape                                    33
#             Robbery                               1160
# Central     Aggravated Assault                     156
#             Homicide                                 3
#             Rape                                     1
#             Robbery                                 56
# Devonshire  Aggravated Assault                      45
#             Robbery                                 18
# Foothill    Aggravated Assault                      94
#             Homicide                                 4
#             Rape                                     2
#             Robbery                                 31
# Harbor      Aggravated Assault                      68
# ...

# %%
f = plt.figure()
plot_df.unstack().plot(kind='bar',ax=f.gca(),stacked=True)
plt.title('Arrests by Area', color='black')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.savefig('Arrests by area.png', bbox_inches='tight')
plt.show()

# %%
f = plt.figure()
hc_locations_df.unstack().plot(kind='bar',ax=f.gca(),stacked=True)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.title('Serious Arrests', color='black')
plt.savefig('hc_locations.png', bbox_inches='tight')
plt.show()

# %%
f=plt.figure()
wcc_locations_df.unstack().plot(kind='bar',ax=f.gca(),stacked=True)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.title('Money Arrests', color='black')
plt.savefig('wcc_locations.png', bbox_inches='tight')
plt.show()

# %%
f=plt.figure()
bfc_locations_df.unstack().plot(kind='bar',ax=f.gca(),stacked=True)
plt.title('Vehicle Arrests', color='black')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.savefig('bfc_locations.png', bbox_inches='tight')
plt.show()

# %%
colors
# Out:
# {'Southwest': 'red',
#  '77th Street': 'blue',
#  'Pacific': 'yellow',
#  'Southeast': 'orange',
#  'Hollywood': 'purple'}

# %%
#Creating a graph for most occurred crime in an area
## importing libraries
from matplotlib.lines import Line2D
cmap = plt.cm.coolwarm

#create variables for setting color values
tester=plot_df.reset_index(inplace=False)
mycolors = ['red','blue','yellow','orange','purple']
myitems = most_occurred_crime['Charge Group Description'].unique()
colors = {}
mycolors_legend = []
#loop to assign colors to charges
for i in range(len(mycolors)):
    colors[myitems[i]] = mycolors[i]
    mycolors_legend.append(myitems[i])
myco = []
for i in range(len(most_occurred_crime)):
    myco.append(colors[most_occurred_crime['Charge Group Description'][i]])
    
#creating the dataframe of the most occurred crime by area  
most_occurred_crime=tester.merge(tester.loc[tester.groupby('Area Name')['Number of Crimes'].idxmax(), ['Area Name', 'Charge Group Description']])
most_occurred_crime=most_occurred_crime.set_index('Area Name')

#seting parameters for graph
height = list(most_occurred_crime['Number of Crimes'])
bars = tuple(most_occurred_crime.index)#['Charge Group Description'])
y_pos = np.arange(len(bars))

plt.bar(y_pos, height, color=tuple(myco))
plt.xticks(y_pos, bars,rotation=90)
ke = []
custom_lines = []
for key,val in colors.items():
    custom_lines.append(Line2D([0], [0], color=val, lw=4))
    ke.append(key)
plt.legend(custom_lines,ke,loc='center left', bbox_to_anchor=(1.0, 0.5))

plt.title('Top arrests by Area', color='black')
plt.savefig('most_ocurred_crime_by_location.png',bbox_inches='tight')


plt.show()

# %%
#reworking groups in df_area to make a dataframe to find the top crime commited in each district
biggest_crime_in_district=df_area.groupby(["Charge Group Description"])["Area Name"].value_counts()
bcid_df=pd.DataFrame(biggest_crime_in_district)
bcid_df.columns=['Number of Crimes']
top_crime_list=[]
for crime in crimes:

    crime_variable=bcid_df.loc[[(crime)]]
    top_crime_list.append(crime_variable.iloc[[0]])
tc_df = pd.concat(top_crime_list)

tc_df.reset_index(inplace=True)

tc_df.set_index(['Charge Group Description'],inplace=True)

# %%
#Creating a graph for top crime by area
##same legend making process as above
mycolors = ['red','blue','yellow','orange','purple']
myitems = tc_df['Area Name'].unique()
colors = {}
mycolors_legend = []

for i in range(len(mycolors)):
    colors[myitems[i]] = mycolors[i]
    mycolors_legend.append(myitems[i])
myco = []
for i in range(len(tc_df)):
    myco.append(colors[tc_df['Area Name'][i]])

height = list(tc_df['Number of Crimes'])
bars = tuple(tc_df.index)#['Charge Group Description'])
y_pos = np.arange(len(bars))

plt.bar(y_pos, height, color=tuple(myco))
plt.xticks(y_pos, bars,rotation=90)
ke = []
custom_lines = []
for key,val in colors.items():
    custom_lines.append(Line2D([0], [0], color=val, lw=4))
    ke.append(key)
plt.legend(custom_lines,ke,loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.title('Location where most arrests occur', color='black')

plt.savefig('total_crime_by_area.png',bbox_inches='tight')
plt.show()

# %%
#with more time:
    #map coordinates to a map layover
    #stat values for each type of crime
